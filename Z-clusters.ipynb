# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
Data=pd.read_excel('Semestr2.xlsx', sheet_name='z-clusters') 
Data.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0         NaN   -0.238426    0.464706    0.356321    0.041020   -0.124397  \
# 1         NaN   -0.068775   -0.830018    0.296487   -0.414639   -0.656095
# 2         NaN   -0.221461   -0.745842   -1.221792   -0.730325   -0.300407
# 3         NaN   -0.417771   -0.049574   -3.166385   -1.445084   -0.227070
# 4         NaN    0.103300   -0.771449   -0.840352   -0.655871   -0.392079
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0   -0.220938   -0.544777   -0.632544
# 1   -0.220596   -0.720833   -0.657630
# 2    0.127906    1.215783   -0.005396
# 3   -0.220938   -0.944904   -0.682715
# 4    1.109658    1.439854    0.270549

# %%
newData=Data.iloc[:,[1,2,3,4,5,6,7,8]].values

# %%
from sklearn.cluster import AgglomerativeClustering 
Agg_hc = AgglomerativeClustering(n_clusters = 6, affinity = 'euclidean', linkage = 'ward')
y_hc = Agg_hc.fit_predict(newData)
plt.scatter(newData[y_hc == 0, 0], newData[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1') 
plt.scatter(newData[y_hc == 1, 0], newData[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2') 
plt.scatter(newData[y_hc == 2, 0], newData[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3') 
plt.scatter(newData[y_hc == 3, 0], newData[y_hc == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')  
plt.scatter(newData[y_hc == 4, 0], newData[y_hc == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(newData[y_hc == 5, 0], newData[y_hc == 5, 1], s = 100, c = 'yellow', label = 'Cluster 6')

plt.legend()
plt.show()
# Out:
# C:\Users\Xiaomi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
Agg_hc = AgglomerativeClustering(n_clusters = 6, affinity = 'euclidean', linkage = 'complete')
y_hc = Agg_hc.fit_predict(newData) # model fitting on the dataset
plt.scatter(newData[y_hc == 0, 0], newData[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1') 
plt.scatter(newData[y_hc == 1, 0], newData[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2') 
plt.scatter(newData[y_hc == 2, 0], newData[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3') 
plt.scatter(newData[y_hc == 3, 0], newData[y_hc == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(newData[y_hc == 4, 0], newData[y_hc == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(newData[y_hc == 5, 0], newData[y_hc == 5, 1], s = 100, c = 'yellow', label = 'Cluster 6')

plt.legend()

plt.show()
# Out:
# C:\Users\Xiaomi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
Agg_hc = AgglomerativeClustering(n_clusters = 6, affinity = 'euclidean', linkage = 'single')
y_hc = Agg_hc.fit_predict(newData) 
plt.scatter(newData[y_hc == 0, 0], newData[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1') 
plt.scatter(newData[y_hc == 1, 0], newData[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2') 
plt.scatter(newData[y_hc == 2, 0], newData[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3') 
plt.scatter(newData[y_hc == 3, 0], newData[y_hc == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')  
plt.scatter(newData[y_hc == 4, 0], newData[y_hc == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(newData[y_hc == 5, 0], newData[y_hc == 5, 1], s = 100, c = 'yellow', label = 'Cluster 6')

plt.legend()
plt.show()
# Out:
# C:\Users\Xiaomi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
Agg_hc = AgglomerativeClustering(n_clusters = 6, affinity = 'euclidean', linkage = 'average')
y_hc = Agg_hc.fit_predict(newData)
plt.scatter(newData[y_hc == 0, 0], newData[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1') 
plt.scatter(newData[y_hc == 1, 0], newData[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(newData[y_hc == 2, 0], newData[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3')  
plt.scatter(newData[y_hc == 3, 0], newData[y_hc == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')  
plt.scatter(newData[y_hc == 4, 0], newData[y_hc == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(newData[y_hc == 5, 0], newData[y_hc == 5, 1], s = 100, c = 'yellow', label = 'Cluster 6')

plt.legend()
plt.show()
# Out:
# C:\Users\Xiaomi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
