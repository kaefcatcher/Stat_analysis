# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
import seaborn as sns

# %%
df=pd.read_excel('Semestr2.xlsx', sheet_name='for_python2')

# %%
df.describe()
# Out:
#        Индекс потребительских цен, 2010 г.=100
# count                                47.000000  \
# mean                                119.878723
# std                                  42.596228
# min                                  98.200000
# 25%                                 106.850000
# 50%                                 108.600000
# 75%                                 114.450000
# max                                 387.100000
#
#        Расходы на конечное потребление на душу населения в долл. США
# count                                          47.000000               \
# mean                                        29328.968085
# std                                         23013.911509
# min                                          2802.500000
# 25%                                         15922.650000
# 50%                                         26098.800000
# 75%                                         37701.300000
# ...

# %%
scaler=StandardScaler()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Индекс потребительских цен, 2010 г.=100',
#        'Расходы на конечное потребление на душу населения в долл. США ',
#        'Внешний баланс товаров и услуг, % от ВВП',
#        'Экспорт товаров и услуг, доля в процентах от ВВП',
#        'Импорт товаров и услуг, доля в процентах от ВВП',
#        'Обменный курс, единиц национальной валюты за долл. США',
#        'Уровень безработицы, %',
#        'ВВП на душу населения в ценах и ППС(США) 2010 г., темп роста'],
#       dtype='object')

# %%
kmeans= KMeans(n_clusters=6)

# %%
kmeans.fit(df[['Индекс потребительских цен, 2010 г.=100',
       'ВВП на душу населения в ценах и ППС(США) 2010 г., темп роста']])
# Out:
# C:\Users\Xiaomi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=6)

# %%
df['kmeans_6'] = kmeans.labels_

# %%
df
# Out:
#                    Unnamed: 0  Индекс потребительских цен, 2010 г.=100
# 0                     Австрия                                    110.7  \
# 1                 Азербайджан                                    117.7
# 2                     Албания                                    111.4
# 3                     Андорра                                    103.3
# 4                     Армения                                    124.8
# 5                    Беларусь                                    387.1
# 6                     Бельгия                                    108.6
# 7                    Болгария                                    106.6
# 8                     Венгрия                                    111.4
# 9                    Германия                                    107.2
# 10                     Греция                                    100.8
# 11                     Грузия                                    114.7
# ...

# %%
means = df.iloc[:, 2:].groupby('kmeans_6').mean()
means
# Out:
#           Расходы на конечное потребление на душу населения в долл. США
# kmeans_6
# 0                                              12363.420000               \
# 1                                              12856.600000
# 2                                              29620.492593
# 3                                               5298.100000
# 4                                              57008.928571
# 5                                              18875.160000
#
#           Внешний баланс товаров и услуг, % от ВВП
# kmeans_6
# 0                                       -12.260000  \
# 1                                         0.100000
# 2                                         2.111111
# 3                                         2.450000
# 4                                        -2.300000
# 5                                        -3.900000
#
#           Экспорт товаров и услуг, доля в процентах от ВВП
# kmeans_6
# 0                                                27.700000  \
# ...

# %%
clusters = df.groupby('kmeans_6')
sns.set_style('whitegrid')

# создание графика
fig, ax = plt.subplots(figsize=(10, 6))

# отрисовка точек для каждого кластера
for name, cluster in clusters:
    ax.scatter(cluster['Импорт товаров и услуг, доля в процентах от ВВП'], cluster['ВВП на душу населения в ценах и ППС(США) 2010 г., темп роста'], 
               s=100, alpha=0.8, label=name)

# добавление легенды
ax.legend(title='Кластер')




# отображение графика
plt.show()
